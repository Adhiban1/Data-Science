# %%
import pandas as pd

# %%
df = pd.read_csv('dataset\Salary_Dataset_with_Extra_Features.csv')

# %%
df.head()
# Out:
#    Rating                      Company Name          Job Title   Salary  \
# 0     3.8                            Sasken  Android Developer   400000
# 1     4.5  Advanced Millennium Technologies  Android Developer   400000
# 2     4.0                         Unacademy  Android Developer  1000000
# 3     3.8                SnapBizz Cloudtech  Android Developer   300000
# 4     4.4            Appoids Tech Solutions  Android Developer   600000
#
#    Salaries Reported   Location Employment Status Job Roles
# 0                  3  Bangalore         Full Time   Android
# 1                  3  Bangalore         Full Time   Android
# 2                  3  Bangalore         Full Time   Android
# 3                  3  Bangalore         Full Time   Android
# 4                  3  Bangalore         Full Time   Android

# %%
temp = []
for i in df['Job Title']:
    if 'Python' in i:
        temp.append(True)
    else: temp.append(False)
df1 = df[temp]

# %%
df2 = df1.groupby('Job Title').mean().sort_values('Salary', ascending=False)['Salary'].to_frame().reset_index()
df2.columns = ['Job Title', 'Average Salary']
df2 = df2.drop_duplicates()
df2
# Out:
#                                     Job Title  Average Salary
# 0         Software Engineer(Python Developer)       1800000.0
# 1                     Python Bigdata Engineer       1600000.0
# 2                       Python Data scientist       1500000.0
# 3                    Python Freelance Trainer       1453056.0
# 4                Python Testing and Debugging       1400000.0
# ..                                        ...             ...
# 111       Python and Machine Learning Analyst        100000.0
# 112              Python AI Developer - Intern         60000.0
# 113         Python Software Engineer - Intern         60000.0
# 114    Full Stack Python Developer Contractor         60000.0
# 115  Python Django Developer Trainee - Intern         60000.0
#
# [116 rows x 2 columns]

# %%
df1 = df1.sort_values('Job Title')

# %%
df1 = df1[['Rating', 'Company Name', 'Job Title', 'Salary',
       'Location', 'Employment Status']]

# %%
df1.Salary = df1.Salary/100000

# %%
df1.columns = ['Rating', 'Company Name', 'Job Title', 'Salary (L)/Year', 'Location',
       'Employment Status']

# %%
df1.head()
# Out:
#        Rating                    Company Name  \
# 11363     3.9       Tata Consultancy Services
# 11840     3.8  Cognizant Technology Solutions
# 11543     4.2                          Contus
# 11305     3.9       Tata Consultancy Services
# 11830     3.9       Tata Consultancy Services
#
#                                      Job Title  Salary (L)/Year   Location  \
# 11363                   .NET Developer, Python             4.68  Bangalore
# 11840                Advanced Python Developer             5.28  Hyderabad
# 11543  Applications Developer/Python Developer             1.92    Chennai
# 11305                    As A Python Developer             4.00  Bangalore
# 11830                    As A Python Developer             4.00  Hyderabad
#
#       Employment Status
# 11363         Full Time
# 11840         Full Time
# 11543         Full Time
# 11305         Full Time
# 11830         Full Time

# %%
df1.to_csv('Python Jobs.csv', index=False)

# %%
df2['Average Salary'] = df2['Average Salary']/100000

# %%
df2.columns = ['Job Title', 'Average Salary (L)/Year']

# %%
df2['Average Salary (L)/Year'] = df2['Average Salary (L)/Year'].round(2)

# %%
df2.head()
# Out:
#                              Job Title  Average Salary (L)/Year
# 0  Software Engineer(Python Developer)                    18.00
# 1              Python Bigdata Engineer                    16.00
# 2                Python Data scientist                    15.00
# 3             Python Freelance Trainer                    14.53
# 4         Python Testing and Debugging                    14.00

# %%
df2.to_csv('Python Average Salary.csv', index=False)

# %%
for i,j in enumerate(df2['Job Title']):
    print(f'{i+1}. {j}')
# Out:
# 1. Software Engineer(Python Developer)
# 2. Python Bigdata Engineer
# 3. Python Data scientist
# 4. Python Freelance Trainer
# 5. Python Testing and Debugging
# 6. Lead Python Developer
# 7. Python Devolper
# 8. Python Test Engineer
# 9. SDE2 - Python
# 10. Hadoop, Python, Jsp Servlet, C++ Developer - Intern
# 11. Python Automation Engineer - Contractor
# 12. Sr. Python Developer/Software Engineer
# 13. Senior Python Engineer
# 14. Python Automation - Intern
# 15. Python Automation QA
# 16. Ethical Hacking and Python
# 17. Senior Python Developer - Contractor
# 18. Software Engineer(Python Programmer)
# 19. Python/Django Developer - Contractor
# 20. Senior Python Programmer
# 21. Senior Python Developer
# 22. Python Developer/Nodejs Developer
# 23. Python Automation Tester - Contractor
# 24. Python Content Developer
# 25. Python (AI/Ml) Developer
# 26. Python Backend Developer
# 27. Python and Shell Scripting Developer
# 28. Python Automation Tester
# ...
