# %%
import pandas as pd

# %%
df = pd.read_csv('12000 Data Science Jobs in India - Naukri.com/naukri_data_science_jobs_india.csv')
df
# Out:
#                                                 Job_Role  \
# 0                                  Senior Data Scientist
# 1                                  Senior Data Scientist
# 2      Applied Data Scientist / ML Senior Engineer (P...
# 3                                         Data Scientist
# 4                                         Data Scientist
# ...                                                  ...
# 11995                Tech Lead/Architect ( Contractual )
# 11996                               Tech Lead / POD Lead
# 11997     Java Full Stack Developer - Hibernate / Spring
# 11998                                  Tech Lead - Azure
# 11999            Full Stack Developer - Machine Learning
#
#                                   Company  \
# 0                                     UPL
# 1                                 Walmart
# 2                       SAP India Pvt.Ltd
# 3                                     UPL
# 4                                 Walmart
# ...

# %%
df1 = df[df.Job_Role.str.contains('Data Scientist', case=False)]
df1 = df1[df1.Location.str.contains('Chennai')]
df1
# Out:
#                                                Job_Role  \
# 9     Sr Data Scientist / Lead Data Scientist | Geak...
# 11               Data Scientist / Senior Data Scientist
# 20    Manager, Data Scientist/AI and Machine Learnin...
# 27    Manager, Senior Clinical Data Scientist, Clini...
# 35                       Sr Data Scientist and Engineer
# ...                                                 ...
# 1403                              Data Scientist Intern
# 1404                              Data Scientist Intern
# 1420                   Data Scientist Senior Consultant
# 6698               opening For Data Scientist_Hyderabad
# 7677                       Data Scientist_Life Sciences
#
#                                            Company  \
# 9           Geakminds Technologies Private Limited
# 11    Tredence Analytics Solutions Private Limited
# 20                                          Pfizer
# 27                                          Pfizer
# ...

# %%
df1['Job Experience'].value_counts()
# Out:
# 3-8      15
# 5-10     15
# 4-8      11
# 4-9      10
# 2-6       7
# 6-11      6
# 10-14     5
# 2-7       4
# 5-9       4
# 5-8       4
# 3-7       4
# 3-5       3
# 10-15     3
# 5-7       3
# 0-1       3
# 1-5       3
# 2-5       3
# 3-6       2
# 8-13      2
# 0-2       2
# 7-12      2
# 6-10      2
# 6-9       2
# 1-2       1
# 6-8       1
# 8-12      1
# 2-3       1
# 8-10      1
# 10-12     1
# 4-6       1
# 2-4       1
# 3-9       1
# 10-16     1
# 3-4       1
# 0-4       1
# 10-20     1
# 1-4       1
# 9-14      1
# 12-18     1
# Name: Job Experience, dtype: int64
